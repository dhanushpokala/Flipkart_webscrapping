# %%
# !pip install requests

# %%
# !pip install bs4
import requests
from bs4 import BeautifulSoup

# %%
res =requests.get(url='https://www.flipkart.com/search?q=samsung+mobiles&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&as-pos=1&as-type=RECENT&suggestionId=samsung+mobiles%7CMobiles&requestId=fbddc761-ea74-418c-9921-7a5a02a1757e&as-searchtext=sam')

# %%
res
# Out:
# <Response [200]>

# %%
res.content
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.8a1772.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/><link rel="apple-touch-icon" sizes="72x72" href="/apple-touch-icon-72x72.png"/><link rel="app
# ...

# %%
soup=BeautifulSoup(res.content,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
soup.find_all('div', class_="_4rR01T")
# Out:
# [<div class="_4rR01T">SAMSUNG Galaxy F22 (Denim Blue, 128 GB)</div>,
#  <div class="_4rR01T">SAMSUNG Galaxy F12 (Celestial Black, 64 GB)</div>,
#  <div class="_4rR01T">SAMSUNG Galaxy F22 (Denim Blue, 64 GB)</div>,
#  <div class="_4rR01T">SAMSUNG Galaxy F22 (Denim Black, 64 GB)</div>,
#  <div class="_4rR01T">SAMSUNG Galaxy F12 (Sky Blue, 64 GB)</div>,
#  <div class="_4rR01T">SAMSUNG Galaxy M12 (Black, 64 GB)</div>,
#  <div class="_4rR01T">SAMSUNG Galaxy M12 (White, 128 GB)</div>,
#  <div class="_4rR01T">SAMSUNG Galaxy F12 (Sea Green, 64 GB)</div>,
#  <div class="_4rR01T">SAMSUNG Galaxy F22 (Denim Black, 128 GB)</div>,
#  <div class="_4rR01T">SAMSUNG Galaxy M12 (Blue, 64 GB)</div>,
#  <div class="_4rR01T">SAMSUNG Galaxy M31 (Space Black, 128 GB)</div>,
#  <div class="_4rR01T">SAMSUNG Galaxy M31 (Iceberg blue, 128 GB)</div>,
#  <div class="_4rR01T">SAMSUNG S20 FE 5G (Cloud Navy, 128 GB)</div>,
#  <div class="_4rR01T">SAMSUNG Galaxy M12 (Black, 128 GB)</div>,
# ...

# %%
rows=soup.findAll('div', class_="_30jeq3 _1_WHN1")

# %%
l2=[]
for row in rows:
    l2.append(row.getText())
    
l2
# Out:
# ['₹14,999',
#  '₹11,499',
#  '₹12,999',
#  '₹12,999',
#  '₹11,499',
#  '₹11,196',
#  '₹13,971',
#  '₹11,499',
#  '₹14,999',
#  '₹11,296',
#  '₹18,949',
#  '₹18,999',
#  '₹39,464',
#  '₹14,386',
#  '₹19,998',
#  '₹28,489',
#  '₹14,199',
#  '₹22,999',
#  '₹19,989',
#  '₹8,429',
#  '₹9,919',
#  '₹20,999',
#  '₹19,999',
#  '₹13,470']

# %%
rows1=soup.find_all('div', class_="_4rR01T")

# %%
l1=[]
for row in rows1:
    l1.append(row.getText())
    
l1
# Out:
# ['SAMSUNG Galaxy F22 (Denim Blue, 128 GB)',
#  'SAMSUNG Galaxy F12 (Celestial Black, 64 GB)',
#  'SAMSUNG Galaxy F22 (Denim Blue, 64 GB)',
#  'SAMSUNG Galaxy F22 (Denim Black, 64 GB)',
#  'SAMSUNG Galaxy F12 (Sky Blue, 64 GB)',
#  'SAMSUNG Galaxy M12 (Black, 64 GB)',
#  'SAMSUNG Galaxy M12 (White, 128 GB)',
#  'SAMSUNG Galaxy F12 (Sea Green, 64 GB)',
#  'SAMSUNG Galaxy F22 (Denim Black, 128 GB)',
#  'SAMSUNG Galaxy M12 (Blue, 64 GB)',
#  'SAMSUNG Galaxy M31 (Space Black, 128 GB)',
#  'SAMSUNG Galaxy M31 (Iceberg blue, 128 GB)',
#  'SAMSUNG S20 FE 5G (Cloud Navy, 128 GB)',
#  'SAMSUNG Galaxy M12 (Black, 128 GB)',
#  'SAMSUNG Galaxy A22 5G (Violet, 128 GB)',
#  'SAMSUNG Galaxy A52 (Awesome Black, 128 GB)',
#  'SAMSUNG Galaxy M12 (Blue, 128 GB)',
#  'SAMSUNG Galaxy F42 5G (Matte Black, 128 GB)',
#  'SAMSUNG Galaxy A22 5G (Mint, 128 GB)',
#  'SAMSUNG Galaxy M02 (Gray, 32 GB)',
#  'SAMSUNG M02s (Blue, 32 GB)',
#  'SAMSUNG Galaxy F42 5G (Matte Black, 128 GB)',
# ...

# %%
s={l1[i]:l2[i] for i in range(len(l2))}
s
# Out:
# {'SAMSUNG Galaxy F22 (Denim Blue, 128 GB)': '₹14,999',
#  'SAMSUNG Galaxy F12 (Celestial Black, 64 GB)': '₹11,499',
#  'SAMSUNG Galaxy F22 (Denim Blue, 64 GB)': '₹12,999',
#  'SAMSUNG Galaxy F22 (Denim Black, 64 GB)': '₹12,999',
#  'SAMSUNG Galaxy F12 (Sky Blue, 64 GB)': '₹11,499',
#  'SAMSUNG Galaxy M12 (Black, 64 GB)': '₹11,196',
#  'SAMSUNG Galaxy M12 (White, 128 GB)': '₹13,971',
#  'SAMSUNG Galaxy F12 (Sea Green, 64 GB)': '₹11,499',
#  'SAMSUNG Galaxy F22 (Denim Black, 128 GB)': '₹14,999',
#  'SAMSUNG Galaxy M12 (Blue, 64 GB)': '₹11,296',
#  'SAMSUNG Galaxy M31 (Space Black, 128 GB)': '₹18,949',
#  'SAMSUNG Galaxy M31 (Iceberg blue, 128 GB)': '₹18,999',
#  'SAMSUNG S20 FE 5G (Cloud Navy, 128 GB)': '₹39,464',
#  'SAMSUNG Galaxy M12 (Black, 128 GB)': '₹14,386',
#  'SAMSUNG Galaxy A22 5G (Violet, 128 GB)': '₹19,998',
#  'SAMSUNG Galaxy A52 (Awesome Black, 128 GB)': '₹28,489',
#  'SAMSUNG Galaxy M12 (Blue, 128 GB)': '₹14,199',
# ...
